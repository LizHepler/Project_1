# %%
# Import relevant libraries
import requests
import json
import hvplot.pandas
import pandas as pd
from scipy.stats import linregress
from matplotlib import pyplot as plt
import random


from config import api_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="f345b4a4-717a-4e3b-be77-fb65f8b14f09" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"8eda4877-625f-41e8-9f2a-a678dafe203f":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"7b0696483e28452ba32b83f08360b040","client_comm_id":"f6f108c2f1c94cc59e3e691c1716dcde"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"8eda4877-625f-41e8-9f2a-a678dafe203f","roots":{"p1002":"f345b4a4-717a-4e3b-be77-fb65f8b14f09"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
# Read in data from CSV to DataFrame
path = "./NY-House-Dataset.csv"
housing_df = pd.read_csv(path,index_col=False)

# %%
# Clean up data
def checknumeric(txt):
    return txt.isnumeric()

wrong_df = housing_df.loc[(housing_df["ADMINISTRATIVE_AREA_LEVEL_2"].apply(checknumeric)) | (housing_df["PRICE"] > 5000000)]
remove = wrong_df.index
housing_df = housing_df.drop(labels=remove)
housing_df = housing_df.drop(labels=["MAIN_ADDRESS","ADMINISTRATIVE_AREA_LEVEL_2","STREET_NAME","LONG_NAME", "FORMATTED_ADDRESS"], axis = 1)
housing_df.reset_index(drop=True,inplace=True)
housing_df
# Out:
#                                         BROKERTITLE            TYPE    PRICE  \
# 0       Brokered by Douglas Elliman  -111 Fifth Ave  Condo for sale   315000
# 1                            Brokered by Sowae Corp  House for sale   260000
# 2                               Brokered by COMPASS  Condo for sale    69000
# 3                            Brokered by Sowae Corp  House for sale   690000
# 4     Brokered by Douglas Elliman - 575 Madison Ave  Condo for sale   899500
# ...                                             ...             ...      ...
# 4444                            Brokered by COMPASS  Co-op for sale   599000
# 4445                Brokered by Mjr Real Estate Llc  Co-op for sale   245000
# 4446  Brokered by Douglas Elliman - 575 Madison Ave  Co-op for sale  1275000
# 4447        Brokered by E Realty International Corp  Condo for sale   598125
# 4448             Brokered by Nyc Realty Brokers Llc  Co-op for sale   349000
#
#       BEDS  BATH  PROPERTYSQFT                    ADDRESS  \
# 0        2   2.0   1400.000000       2 E 55th St Unit 803
# 1        4   2.0   2015.000000           620 Sinclair Ave
# 2        3   1.0    445.000000    2 E 55th St Unit 908W33
# 3        5   2.0   4004.000000                584 Park Pl
# 4        2   2.0   2184.207862     157 W 126th St Unit 1B
# ...    ...   ...           ...                        ...
# 4444     1   1.0   2184.207862       222 E 80th St Apt 3A
# 4445     1   1.0   2184.207862        97-40 62 Dr Unit Lg
# 4446     1   1.0   2184.207862  427 W 21st St Unit Garden
# 4447     2   1.0    655.000000   91-23 Corona Ave Unit 4G
# 4448     1   1.0    750.000000    460 Neptune Ave Apt 14O
#
#                         STATE         LOCALITY      SUBLOCALITY   LATITUDE  \
# 0          New York, NY 10022         New York        Manhattan  40.761255
# 1     Staten Island, NY 10312         New York  Richmond County  40.541805
# 2         Manhattan, NY 10022         New York  New York County  40.761398
# 3          Brooklyn, NY 11238         New York     Kings County  40.674363
# 4          New York, NY 10027  New York County         New York  40.809448
# ...                       ...              ...              ...        ...
# 4444      Manhattan, NY 10075  New York County         New York  40.774350
# 4445      Rego Park, NY 11374         New York    Queens County  40.732538
# 4446       New York, NY 10011         New York  New York County  40.745882
# 4447       Elmhurst, NY 11373    Queens County           Queens  40.742770
# 4448       Brooklyn, NY 11224     Kings County         Brooklyn  40.579147
#
#       LONGITUDE
# 0    -73.974483
# 1    -74.196109
# 2    -73.974613
# 3    -73.958725
# 4    -73.946777
# ...         ...
# 4444 -73.955879
# 4445 -73.860152
# 4446 -74.003398
# 4447 -73.872752
# 4448 -73.970949
#
# [4449 rows x 12 columns]

# %%
def plot_lin_regress(x,y,xlabel,ylabel,title,loc):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x,y)
    plt.plot(x,regress_values,"r-")
    plt.annotate(line_eq,loc,fontsize=15,color="red")
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    file_name = title.replace(" ","_")
    plt.savefig("output/"+file_name)
    return rvalue

# %%
# General housing graphs
data = pd.DataFrame(housing_df)
aggregation = data.groupby('TYPE').agg({
    'BEDS': 'mean',
    'BATH': 'mean',
    'PRICE': 'mean',
    'PROPERTYSQFT': 'mean'
}).reset_index()

# Bar graphs of housing prices, rooms, etc.
# Plot 1: Average Price by House Type
plt.figure(figsize=(12, 8))
plt.bar(aggregation['TYPE'], aggregation['PRICE'], color='skyblue')
plt.title('Average House Price by Type')
plt.xlabel('House Type')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout() 
plt.savefig("./output/AveragePricebyHouseType")
plt.show()

# Plot 2: Average Number of Bedrooms by House Type
plt.figure(figsize=(12, 8))
plt.bar(aggregation['TYPE'], aggregation['BEDS'], color='lightgreen')
plt.title('Average Number of Bedrooms by Type')
plt.xlabel('House Type')
plt.ylabel('Average Number of Bedrooms')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()  
plt.savefig("./output/AverageBedroomsbyHouseType")
plt.show()

# Plot 3: Average Number of Bathrooms by House Type
plt.figure(figsize=(12, 8))
plt.bar(aggregation['TYPE'], aggregation['BATH'], color='lightcoral')
plt.title('Average Number of Bathrooms by Type')
plt.xlabel('House Type')
plt.ylabel('Average Number of Bathrooms')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout() 
plt.savefig("./output/AverageBathroomsbyHouseType")
plt.show()

# Plot 4: Average Property Square Feet by House Type
plt.figure(figsize=(12, 8))
plt.bar(aggregation['TYPE'], aggregation['PROPERTYSQFT'], color='lightgoldenrodyellow')
plt.title('Average Property Square Feet by Type')
plt.xlabel('House Type')
plt.ylabel('Average Property Square Feet')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()  
plt.savefig("./output/AverageSqrFtbyHouseType")
plt.show()

# %%
# Pie chart of house types
type_counts = housing_df["TYPE"].value_counts()
type_df = pd.DataFrame(type_counts).reset_index()
type_df

reduced_df = type_df[:6].copy()
others_df = pd.DataFrame({"TYPE": ["Others"], "count": [type_df["count"][6:].sum()]})

reduced_df = pd.concat([reduced_df, others_df])
reduced_df

explode = (0.1, 0, 0, 0, 0, 0, 0)

plt.pie(reduced_df["count"], labels=reduced_df["TYPE"], autopct='%1.1f%%', shadow=True, startangle=180, explode=explode)
plt.savefig("./output/PieChartHouseTypes")
plt.show()

# %%
coop_df = housing_df[housing_df["TYPE"] == "Co-op for sale"]
coop_df
# Out:
#                                         BROKERTITLE            TYPE    PRICE  \
# 5                    Brokered by Pantiga Group Inc.  Co-op for sale   265000
# 6                  Brokered by CENTURY 21 MK Realty  Co-op for sale   440000
# 7              Brokered by Engel & Volkers Americas  Co-op for sale   375000
# 9                               Brokered by COMPASS  Co-op for sale   259000
# 10       Brokered by Jamie & Connie Real Estate Grp  Co-op for sale   430000
# ...                                             ...             ...      ...
# 4441                   Brokered by Engel & V�������  Co-op for sale  1950000
# 4444                            Brokered by COMPASS  Co-op for sale   599000
# 4445                Brokered by Mjr Real Estate Llc  Co-op for sale   245000
# 4446  Brokered by Douglas Elliman - 575 Madison Ave  Co-op for sale  1275000
# 4448             Brokered by Nyc Realty Brokers Llc  Co-op for sale   349000
#
#       BEDS  BATH  PROPERTYSQFT                      ADDRESS  \
# 5        1   1.0    750.000000      875 Morrison Ave Apt 3M
# 6        2   1.0    978.000000       1350 Ocean Pkwy Apt 5G
# 7        2   1.0    850.000000  800 Grand Concourse Apt 2JS
# 9        3   1.0   2184.207862        34-41 85th St Unit 1D
# 10       2   2.0   2184.207862     91-15 Lamont Ave Unit 6D
# ...    ...   ...           ...                          ...
# 4441     2   4.0   2184.207862        700 Park Ave Unit 20A
# 4444     1   1.0   2184.207862         222 E 80th St Apt 3A
# 4445     1   1.0   2184.207862          97-40 62 Dr Unit Lg
# 4446     1   1.0   2184.207862    427 W 21st St Unit Garden
# 4448     1   1.0    750.000000      460 Neptune Ave Apt 14O
#
#                           STATE         LOCALITY      SUBLOCALITY   LATITUDE  \
# 5               Bronx, NY 10473        The Bronx       East Bronx  40.821586
# 6            Brooklyn, NY 11230     Kings County         Brooklyn  40.615738
# 7               Bronx, NY 10451     Bronx County        The Bronx  40.824870
# 9     Jackson Heights, NY 11372    Queens County           Queens  40.753119
# 10           Elmhurst, NY 11373    Queens County           Queens  40.743864
# ...                         ...              ...              ...        ...
# 4441         New York, NY 10021  New York County         New York  40.769478
# 4444        Manhattan, NY 10075  New York County         New York  40.774350
# 4445        Rego Park, NY 11374         New York    Queens County  40.732538
# 4446         New York, NY 10011         New York  New York County  40.745882
# 4448         Brooklyn, NY 11224     Kings County         Brooklyn  40.579147
#
#       LONGITUDE
# 5    -73.874089
# 6    -73.969694
# 7    -73.922983
# 9    -73.881876
# 10   -73.874572
# ...         ...
# 4441 -73.965389
# 4444 -73.955879
# 4445 -73.860152
# 4446 -74.003398
# 4448 -73.970949
#
# [1401 rows x 12 columns]

# %%
#put Locality with county name into a list
locals = ["Bronx County", "Kings County", "New York County", "Queens County"]

#Create empty list to store prices
pprice = []

#Loop through each locality in the list
for locality in locals:
    # Filter the coop_df Dataframe for the price by locality
    locality_df = coop_df[coop_df["LOCALITY"] == locality]["PRICE"]
    
    # Append the price to list
    pprice.append(locality_df)

    #Calculate the quartiles and IQR
    quartiles = locality_df.quantile([0.25, 0.75])
    lower_q = quartiles[0.25]
    upper_q = quartiles[0.75]
    iqr = upper_q - lower_q

    #Determine potenial outliers
    lower_bound = lower_q - 1.5 * iqr
    upper_bound = upper_q + 1.5 * iqr
    outliers = locality_df[(locality_df < lower_bound) | (locality_df > upper_bound)]

# %%
# Generate a box plot that shows the distribution of prices by locality
data = [pprice[i] for i in range(len(locals))]

#Create the box plot
plt.figure(figsize=(10, 6))
plt.boxplot(data, labels=locals, patch_artist=True, notch=False, vert=90)
plt.title("Co-op Distribution of Price by Locality")
plt.ylabel("Price")
plt.xlabel("Locality")
plt.savefig("./output/CoopPriceByLocality")
plt.show()

# %%
# Scatter plot comparing price to square footage

rvalue = plot_lin_regress(housing_df["PROPERTYSQFT"],housing_df["PRICE"],
                 "PROPERTYSQFT","PRICE","Comparing Price to Square Footage",(5000,0))
print(F"R-Squared equals: {rvalue**2}")

plt.xlabel('Property Size (Sqft)')
plt.ylabel('Price (USD)')
plt.title('Comparing Price to Square Footage')


plt.show()


#include linear regression
# Out:
# R-Squared equals: 0.20102486344432638

# %%
# %%capture --no-display

# Marker Icon API of homes in NY displayed by "type"
NY_homes = housing_df.hvplot.points(
    "LONGITUDE",
    "LATITUDE",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    scale = 1,
    color = "TYPE",
    alpha = 0.5
)
hvplot.save(NY_homes, "./output/AllTypes.html")
NY_homes
# Out:
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: figure(id='p1054', ...)
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [LONGITUDE,LATITUDE]   (TYPE)

# %%
# Narrow down houses that fit "House for sale" criteria 
homes_df = housing_df.loc[(housing_df['TYPE'] == 'House for sale')]
homes_df.head()
# Out:
#                          BROKERTITLE            TYPE   PRICE  BEDS  BATH  \
# 1             Brokered by Sowae Corp  House for sale  260000     4   2.0
# 3             Brokered by Sowae Corp  House for sale  690000     5   2.0
# 17   Brokered by Radiant Estates LLC  House for sale  639999     3   2.0
# 21       Brokered by Elizabeth Marra  House for sale  750000     2   2.0
# 53  Brokered by American Homes Group  House for sale  998800     3   4.0
#
#     PROPERTYSQFT           ADDRESS                    STATE  LOCALITY  \
# 1         2015.0  620 Sinclair Ave  Staten Island, NY 10312  New York
# 3         4004.0       584 Park Pl       Brooklyn, NY 11238  New York
# 17        1260.0      27 Clove Way  Staten Island, NY 10301  New York
# 21        1330.0    280 Loretto St  Staten Island, NY 10307  New York
# 53        2400.0     1191 Clove Rd  Staten Island, NY 10301  New York
#
#         SUBLOCALITY   LATITUDE  LONGITUDE
# 1   Richmond County  40.541805 -74.196109
# 3      Kings County  40.674363 -73.958725
# 17  Richmond County  40.620740 -74.111436
# 21  Richmond County  40.503979 -74.239655
# 53  Richmond County  40.617500 -74.103996

# %%
# %%capture --no-display

# Marker Icon API of 'Houses for sale' by "sublocality"
NY_home = homes_df.hvplot.points(
    "LONGITUDE",
    "LATITUDE",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    #size = "PRICE",
    scale = 1,
    color = "SUBLOCALITY",
    alpha = 0.5,
    hover_cols=["ADDRESS", "PRICE"] 
)
hvplot.save(NY_home, "./output/AllHouses.html")
NY_home
# Out:
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: figure(id='p1266', ...)
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [LONGITUDE,LATITUDE]   (SUBLOCALITY,ADDRESS,PRICE)

# %%
#Narrow down search to homes in Queens using "Sublocality" criteria 
home_df = homes_df.loc[(homes_df['SUBLOCALITY'] == 'Queens County')]
home_df.head()
# Out:
#                                     BROKERTITLE            TYPE    PRICE  \
# 106                      Brokered by Sowae Corp  House for sale   265000
# 110  Brokered by Keller Williams Realty Liberty  House for sale   650000
# 131             Brokered by Corcoran Park Slope  House for sale  1099000
# 133              Brokered by Laffey Real Estate  House for sale   839000
# 134  Brokered by CENTURY 21 PROFESSIONAL REALTY  House for sale   659000
#
#      BEDS  BATH  PROPERTYSQFT           ADDRESS  \
# 106     3   1.0   2184.207862   135-38 224th St
# 110     3   2.0   1522.000000    237-14 93rd Rd
# 131     4   2.0   2184.207862    204-34 9th Ave
# 133     4   2.0   2184.207862    158-35 87th St
# 134     8   3.0   2184.207862  148-05 111th Ave
#
#                              STATE  LOCALITY    SUBLOCALITY   LATITUDE  \
# 106  Springfield Gardens, NY 11413  New York  Queens County  40.675380
# 110            Bellerose, NY 11426  New York  Queens County  40.723245
# 131               Queens, NY 11697  New York  Queens County  40.559561
# 133         Howard Beach, NY 11414  New York  Queens County  40.659091
# 134              Jamaica, NY 11435  New York  Queens County  40.688533
#
#      LONGITUDE
# 106 -73.747257
# 110 -73.729329
# 131 -73.914741
# 133 -73.845197
# 134 -73.796529

# %%
home_df = home_df.copy()

# Add empty columns to the DataFrame to store schools, hospitals, and supermarkets 
home_df.loc[:,"NEARBY SCHOOL"] = ""
home_df.loc[:,"SCHOOL DISTANCE"] = ""
home_df.loc[:,"NEARBY HOSPITAL"] = ""
home_df.loc[:,"HOSPITAL DISTANCE"] = ""
home_df.loc[:,"NEARBY SUPERMARKET"] = ""
home_df.loc[:,"SUPERMARKET DISTANCE"] = ""

home_df.reset_index(drop=True,inplace=True)

# Display sample data
home_df.head()
# Out:
#                                   BROKERTITLE            TYPE    PRICE  BEDS  \
# 0                      Brokered by Sowae Corp  House for sale   265000     3
# 1  Brokered by Keller Williams Realty Liberty  House for sale   650000     3
# 2             Brokered by Corcoran Park Slope  House for sale  1099000     4
# 3              Brokered by Laffey Real Estate  House for sale   839000     4
# 4  Brokered by CENTURY 21 PROFESSIONAL REALTY  House for sale   659000     8
#
#    BATH  PROPERTYSQFT           ADDRESS                          STATE  \
# 0   1.0   2184.207862   135-38 224th St  Springfield Gardens, NY 11413
# 1   2.0   1522.000000    237-14 93rd Rd            Bellerose, NY 11426
# 2   2.0   2184.207862    204-34 9th Ave               Queens, NY 11697
# 3   2.0   2184.207862    158-35 87th St         Howard Beach, NY 11414
# 4   3.0   2184.207862  148-05 111th Ave              Jamaica, NY 11435
#
#    LOCALITY    SUBLOCALITY   LATITUDE  LONGITUDE NEARBY SCHOOL  \
# 0  New York  Queens County  40.675380 -73.747257
# 1  New York  Queens County  40.723245 -73.729329
# 2  New York  Queens County  40.559561 -73.914741
# 3  New York  Queens County  40.659091 -73.845197
# 4  New York  Queens County  40.688533 -73.796529
#
#   SCHOOL DISTANCE NEARBY HOSPITAL HOSPITAL DISTANCE NEARBY SUPERMARKET  \
# 0
# 1
# 2
# 3
# 4
#
#   SUPERMARKET DISTANCE
# 0
# 1
# 2
# 3
# 4

# %%
# Places API of facilities near "homes for sale" in Queens County
radius = 10000
nearest_places = {}

categories = {
    "School": "education.school",
    "Hospital": "healthcare.hospital",
    "Supermarket": "commercial.supermarket"
}

# Get first 100 rows to do API call on
small_df = home_df.iloc[0:100]


for index, row in small_df.iterrows():

    latitude = row["LATITUDE"]
    longitude = row["LONGITUDE"]

    for place_type, category in categories.items():
        params = {
            "categories": category,
            "apiKey": api_key,
            "limit": 5,  
            "filter": f"circle:{longitude},{latitude},{radius}",
            "bias": f"proximity:{longitude},{latitude}"
        }

        base_url = "https://api.geoapify.com/v2/places"
        response = requests.get(base_url, params=params)
        result = response.json()

        
        
        try:
            nearest_places[place_type] = result["features"][0]["properties"]["name"]
            nearest_places[place_type + " Distance"] = result["features"][0]["properties"]["distance"]
        except (KeyError, IndexError):
            nearest_places[place_type + " Distance"] = 10000
            nearest_places[place_type] = "No result found"

    # Print results to corresponding column in the DataFrame
    small_df.loc[index, "NEARBY SCHOOL"] = nearest_places.get("School")
    small_df.loc[index, "SCHOOL DISTANCE"] = nearest_places.get("School Distance")
    small_df.loc[index, "NEARBY HOSPITAL"] = nearest_places.get("Hospital")
    small_df.loc[index, "HOSPITAL DISTANCE"] = nearest_places.get("Hospital Distance")
    small_df.loc[index, "NEARBY SUPERMARKET"] = nearest_places.get("Supermarket")
    small_df.loc[index, "SUPERMARKET DISTANCE"] = nearest_places.get("Supermarket Distance")

    # Print the results for the current home
    print(f"{index+1} of {len(small_df)} - nearest school: {nearest_places.get('School')}, "
          f"nearest hospital: {nearest_places.get('Hospital')}, "
          f"nearest supermarket: {nearest_places.get('Supermarket')}")

# Display the updated DataFrame
small_df.head()
# Out:
# 1 of 100 - nearest school: Christopher Robin Academy, nearest hospital: Saint Albans Community Living Center, nearest supermarket: Key Food
# 2 of 100 - nearest school: No result found, nearest hospital: Creedmor Psychiatric Center, nearest supermarket: Food Marketplace
# 3 of 100 - nearest school: PS 195 Manhattan Beach, nearest hospital: Triborough GI, nearest supermarket: Deirdre Maeve's Market
# 4 of 100 - nearest school: Public School 207, nearest hospital: Brooklyn Developmental Disabilities Services Offices, nearest supermarket: Stop & Shop
# 5 of 100 - nearest school: PS48Q The David N. Dinkins School for Community Service, nearest hospital: Jamaica Hospital Medical Center, nearest supermarket: Titash Super Market
# 6 of 100 - nearest school: PS48Q The David N. Dinkins School for Community Service, nearest hospital: Jamaica Hospital Medical Center, nearest supermarket: Titash Super Market
# 7 of 100 - nearest school: The Yaakov & Ilana Melohn Campus, nearest hospital: Saint John's Episcopal Hospital, nearest supermarket: Shop Fair
# 8 of 100 - nearest school: P.S. 147Q Ronald McNair, nearest hospital: Saint Albans Community Living Center, nearest supermarket: Compare Foods
# 9 of 100 - nearest school: Yeshiva of Belle Harbor, nearest hospital: Triborough GI, nearest supermarket: Rockaway Greens
# 10 of 100 - nearest school: Public School 207, nearest hospital: Brooklyn Developmental Disabilities Services Offices, nearest supermarket: Stop & Shop
# 11 of 100 - nearest school: Public School 169, nearest hospital: Saint Mary's Hospital for Children, nearest supermarket: Stop & Shop
# 12 of 100 - nearest school: PS 148 - The Ruby G Allen School, nearest hospital: Rest Medical Care, nearest supermarket: Key Food
# 13 of 100 - nearest school: Saint Anastasia School, nearest hospital: New York City Children's Center - Queens Campus, nearest supermarket: Food Bazaar
# 14 of 100 - nearest school: No result found, nearest hospital: Flushing Hospital Medical Center, nearest supermarket: GreatWall Supermarket
# 15 of 100 - nearest school: No result found, nearest hospital: Quest Diagnostics, nearest supermarket: New Age Market
# 16 of 100 - nearest school: Saint Francis of Assisi School, nearest hospital: Mount Sinai Queens, nearest supermarket: No result found
# 17 of 100 - nearest school: PS 101Q The School in The Gardens, nearest hospital: Long Island Jewish Forest Hills, nearest supermarket: Vitelio's Marketplace
# 18 of 100 - nearest school: Saints Joachim and Ann School, nearest hospital: Creedmor Psychiatric Center, nearest supermarket: Key Food
# 19 of 100 - nearest school: International Union of Operating Engineers - Local 15 Training, nearest hospital: Brooklyn Developmental Disabilities Services Offices, nearest supermarket: Stop & Shop
# 20 of 100 - nearest school: No result found, nearest hospital: Creedmor Psychiatric Center, nearest supermarket: Cammps
# 21 of 100 - nearest school: No result found, nearest hospital: Wyckoff Heights Medical Center, nearest supermarket: BJ's Wholesale Club
# 22 of 100 - nearest school: Public School 15, nearest hospital: Saint Albans Community Living Center, nearest supermarket: Western Beef Supermarket
# 23 of 100 - nearest school: Campus Magnet Educational Campus, nearest hospital: Saint Albans Community Living Center, nearest supermarket: Compare Foods
# 24 of 100 - nearest school: Public School 207, nearest hospital: Brooklyn Developmental Disabilities Services Offices, nearest supermarket: Stop & Shop
# 25 of 100 - nearest school: Public School 207, nearest hospital: Brooklyn Developmental Disabilities Services Offices, nearest supermarket: Stop & Shop
# 26 of 100 - nearest school: No result found, nearest hospital: Brooklyn Developmental Disabilities Services Offices, nearest supermarket: Grocery Outlet
# 27 of 100 - nearest school: Middle School 226, nearest hospital: Jamaica Hospital Medical Center, nearest supermarket: Key Food
# 28 of 100 - nearest school: Public School 105, nearest hospital: Saint John's Episcopal Hospital, nearest supermarket: Pioneer
# 29 of 100 - nearest school: Our Lady of Perpetual Help School, nearest hospital: Jamaica Hospital Medical Center, nearest supermarket: Key Food
# 30 of 100 - nearest school: PS95Q, nearest hospital: Queens Hospital Center, nearest supermarket: Foodtown
# 31 of 100 - nearest school: Junior High School 194, nearest hospital: Saint Mary's Hospital for Children, nearest supermarket: Jumbo 99 Cent Discount
# 32 of 100 - nearest school: PS 144, nearest hospital: Long Island Jewish Forest Hills, nearest supermarket: Angie’s Market
# 33 of 100 - nearest school: Public School 225, nearest hospital: Saint John's Episcopal Hospital, nearest supermarket: Stop & Shop
# 34 of 100 - nearest school: P.S. 211Q North Hills, nearest hospital: New York City Children's Center - Queens Campus, nearest supermarket: Food Bazaar
# 35 of 100 - nearest school: Immaculate Conception Church, nearest hospital: Queens Hospital Center, nearest supermarket: Al-fattah Food Bazar
# 36 of 100 - nearest school: P.S.174Q William Sidney Mount, nearest hospital: Long Island Jewish Forest Hills, nearest supermarket: Vitelio's Marketplace
# 37 of 100 - nearest school: No result found, nearest hospital: Jamaica Hospital Medical Center, nearest supermarket: C-Town
# 38 of 100 - nearest school: Sacred Hearts School, nearest hospital: Saint Mary's Hospital for Children, nearest supermarket: Foodtown
# 39 of 100 - nearest school: Beach Channel High School, nearest hospital: Saint John's Episcopal Hospital, nearest supermarket: Key Food
# 40 of 100 - nearest school: Public School 159, nearest hospital: Quest Diagnostics, nearest supermarket: H Mart
# 41 of 100 - nearest school: Glen Oaks Campus, nearest hospital: Creedmor Psychiatric Center, nearest supermarket: No result found
# 42 of 100 - nearest school: No result found, nearest hospital: Creedmor Psychiatric Center, nearest supermarket: Key Food
# 43 of 100 - nearest school: Middle School 216, nearest hospital: Queens Hospital Center, nearest supermarket: Fresh Meadows Halal Meat Grocery
# 44 of 100 - nearest school: Saint Virgilius School, nearest hospital: Saint John's Episcopal Hospital, nearest supermarket: Key Food
# 45 of 100 - nearest school: The Summit School, nearest hospital: Queens Hospital Center, nearest supermarket: Khaamar Baari
# 46 of 100 - nearest school: Our Saviour Lutheran School, nearest hospital: Long Island Jewish Forest Hills, nearest supermarket: Met
# 47 of 100 - nearest school: PS 144, nearest hospital: Long Island Jewish Forest Hills, nearest supermarket: Trader Joe's
# 48 of 100 - nearest school: Public School 100, nearest hospital: Jamaica Hospital Medical Center, nearest supermarket: Key Food
# 49 of 100 - nearest school: Corpus Christi School, nearest hospital: Rest Medical Care, nearest supermarket: U-Mart Supermarket
# 50 of 100 - nearest school: No result found, nearest hospital: Saint Mary's Hospital for Children, nearest supermarket: H Mart
# 51 of 100 - nearest school: No result found, nearest hospital: Saint Mary's Hospital for Children, nearest supermarket: H Mart
# 52 of 100 - nearest school: Saints Joachim and Ann School, nearest hospital: Creedmor Psychiatric Center, nearest supermarket: Key Food
# 53 of 100 - nearest school: Public School 207, nearest hospital: Brooklyn Developmental Disabilities Services Offices, nearest supermarket: Stop & Shop
# 54 of 100 - nearest school: No result found, nearest hospital: Flushing Hospital Medical Center, nearest supermarket: H Mart
# 55 of 100 - nearest school: Public School 169, nearest hospital: Saint Mary's Hospital for Children, nearest supermarket: Stop & Shop
# 56 of 100 - nearest school: PS 144, nearest hospital: Long Island Jewish Forest Hills, nearest supermarket: Angie’s Market
# 57 of 100 - nearest school: Phyllis L. Susser School For Exceptional Children, nearest hospital: Queens Hospital Center, nearest supermarket: Union Glaatt Supermarket
# 58 of 100 - nearest school: Saint Anastasia School, nearest hospital: New York City Children's Center - Queens Campus, nearest supermarket: H Mart
# 59 of 100 - nearest school: Public School 100, nearest hospital: Jamaica Hospital Medical Center, nearest supermarket: Key Food
# 60 of 100 - nearest school: Public School 155, nearest hospital: Jamaica Hospital Medical Center, nearest supermarket: Food Universe
# 61 of 100 - nearest school: Junior High School 185, nearest hospital: Flushing Hospital Medical Center, nearest supermarket: H Mart
# 62 of 100 - nearest school: I.S. 230Q School for Civics in the Community, nearest hospital: Rest Medical Care, nearest supermarket: Mina Bazaar
# 63 of 100 - nearest school: No result found, nearest hospital: Quest Diagnostics, nearest supermarket: H Mart
# 64 of 100 - nearest school: PS 176, nearest hospital: Saint Albans Community Living Center, nearest supermarket: Merrick Farm Country
# 65 of 100 - nearest school: Public School 136, nearest hospital: Saint Albans Community Living Center, nearest supermarket: Fine Fare Supermarkets
# 66 of 100 - nearest school: P.S./I.S. 128 Q - Lorraine Tuzzo/Juniper Valley School, nearest hospital: Long Island Jewish Forest Hills, nearest supermarket: C-Town
# 67 of 100 - nearest school: Public School 207, nearest hospital: Brooklyn Developmental Disabilities Services Offices, nearest supermarket: Stop & Shop
# 68 of 100 - nearest school: Bell Academy, nearest hospital: Saint Mary's Hospital for Children, nearest supermarket: Stop & Shop
# 69 of 100 - nearest school: Poppenhusen Institute, nearest hospital: Plaza del Sol Family Health Center, nearest supermarket: All Nations Food Market
# 70 of 100 - nearest school: P.S./I.S. 128 Q - Lorraine Tuzzo/Juniper Valley School, nearest hospital: Wyckoff Heights Medical Center, nearest supermarket: C-Town
# 71 of 100 - nearest school: John Bowne High School, nearest hospital: NewYork-Presbyterian/Queens, nearest supermarket: Yong Fa
# 72 of 100 - nearest school: Public School 165, nearest hospital: Queens Hospital Center, nearest supermarket: Wasserman's Supermarket
# 73 of 100 - nearest school: Public School 209, nearest hospital: Saint Mary's Hospital for Children, nearest supermarket: Jumbo 99 Cent Discount
# 74 of 100 - nearest school: Public School 104, nearest hospital: Saint John's Episcopal Hospital, nearest supermarket: Shop Fair
# 75 of 100 - nearest school: Public School 139, nearest hospital: Long Island Jewish Forest Hills, nearest supermarket: Key Food
# 76 of 100 - nearest school: Queens Gateway to Health Sciences Secondary School, nearest hospital: Queens Hospital Center, nearest supermarket: Foodtown
# 77 of 100 - nearest school: Merrick Academy, nearest hospital: Saint Albans Community Living Center, nearest supermarket: Key Food
# 78 of 100 - nearest school: Public School 155, nearest hospital: Jamaica Hospital Medical Center, nearest supermarket: Food Universe
# 79 of 100 - nearest school: Public School 123, nearest hospital: Jamaica Hospital Medical Center, nearest supermarket: Fine Fare
# 80 of 100 - nearest school: PS 144, nearest hospital: Long Island Jewish Forest Hills, nearest supermarket: Angie’s Market
# 81 of 100 - nearest school: No result found, nearest hospital: Flushing Hospital Medical Center, nearest supermarket: H Mart
# 82 of 100 - nearest school: Public School 193, nearest hospital: Saint Mary's Hospital for Children, nearest supermarket: Jumbo 99 Cent Discount
# 83 of 100 - nearest school: Bayside High School, nearest hospital: Saint Mary's Hospital for Children, nearest supermarket: Stop & Shop
# 84 of 100 - nearest school: Campus Magnet Educational Campus, nearest hospital: Saint Albans Community Living Center, nearest supermarket: Compare Foods
# 85 of 100 - nearest school: Maspeth High School, nearest hospital: Elmhurst Hospital, nearest supermarket: Met
# 86 of 100 - nearest school: Beach Channel High School, nearest hospital: Saint John's Episcopal Hospital, nearest supermarket: Key Food
# 87 of 100 - nearest school: Middle School 226, nearest hospital: Jamaica Hospital Medical Center, nearest supermarket: Key Food
# 88 of 100 - nearest school: Public School Q186 Castlewood, nearest hospital: New York City Children's Center - Queens Campus, nearest supermarket: No result found
# 89 of 100 - nearest school: Holy Trinity School, nearest hospital: Flushing Hospital Medical Center, nearest supermarket: BJ's Wholesale Club
# 90 of 100 - nearest school: Public School Q186 Castlewood, nearest hospital: Zucker Hillside Hospital, nearest supermarket: No result found
# 91 of 100 - nearest school: Public School Q186 Castlewood, nearest hospital: Zucker Hillside Hospital, nearest supermarket: No result found
# 92 of 100 - nearest school: Holy Trinity School, nearest hospital: Flushing Hospital Medical Center, nearest supermarket: BJ's Wholesale Club
# 93 of 100 - nearest school: No result found, nearest hospital: Quest Diagnostics, nearest supermarket: H Mart
# 94 of 100 - nearest school: Public School 207, nearest hospital: Brooklyn Developmental Disabilities Services Offices, nearest supermarket: Stop & Shop
# 95 of 100 - nearest school: No result found, nearest hospital: Creedmor Psychiatric Center, nearest supermarket: Maharaja Farmer's Market
# 96 of 100 - nearest school: Public School 159, nearest hospital: Quest Diagnostics, nearest supermarket: Stop & Shop
# 97 of 100 - nearest school: No result found, nearest hospital: Long Island Jewish Medical Center, nearest supermarket: H Mart
# 98 of 100 - nearest school: Saint Adalbert Catholic Academy, nearest hospital: Elmhurst Hospital, nearest supermarket: Stop & Shop
# 99 of 100 - nearest school: Saint Margaret's Religious Education Center, nearest hospital: Long Island Jewish Forest Hills, nearest supermarket: C-Town
# 100 of 100 - nearest school: Public School 78, nearest hospital: Queens Blvd Extended Care, nearest supermarket: Market Fresh Supermarket
#                                   BROKERTITLE            TYPE    PRICE  BEDS  \
# 0                      Brokered by Sowae Corp  House for sale   265000     3
# 1  Brokered by Keller Williams Realty Liberty  House for sale   650000     3
# 2             Brokered by Corcoran Park Slope  House for sale  1099000     4
# 3              Brokered by Laffey Real Estate  House for sale   839000     4
# 4  Brokered by CENTURY 21 PROFESSIONAL REALTY  House for sale   659000     8
#
#    BATH  PROPERTYSQFT           ADDRESS                          STATE  \
# 0   1.0   2184.207862   135-38 224th St  Springfield Gardens, NY 11413
# 1   2.0   1522.000000    237-14 93rd Rd            Bellerose, NY 11426
# 2   2.0   2184.207862    204-34 9th Ave               Queens, NY 11697
# 3   2.0   2184.207862    158-35 87th St         Howard Beach, NY 11414
# 4   3.0   2184.207862  148-05 111th Ave              Jamaica, NY 11435
#
#    LOCALITY    SUBLOCALITY   LATITUDE  LONGITUDE  \
# 0  New York  Queens County  40.675380 -73.747257
# 1  New York  Queens County  40.723245 -73.729329
# 2  New York  Queens County  40.559561 -73.914741
# 3  New York  Queens County  40.659091 -73.845197
# 4  New York  Queens County  40.688533 -73.796529
#
#                                        NEARBY SCHOOL SCHOOL DISTANCE  \
# 0                          Christopher Robin Academy             289
# 1                                    No result found           10000
# 2                             PS 195 Manhattan Beach            3265
# 3                                  Public School 207             100
# 4  PS48Q The David N. Dinkins School for Communit...             514
#
#                                      NEARBY HOSPITAL HOSPITAL DISTANCE  \
# 0               Saint Albans Community Living Center              2151
# 1                        Creedmor Psychiatric Center              1062
# 2                                      Triborough GI              4316
# 3  Brooklyn Developmental Disabilities Services O...              1578
# 4                    Jamaica Hospital Medical Center              1397
#
#        NEARBY SUPERMARKET SUPERMARKET DISTANCE
# 0                Key Food                  345
# 1        Food Marketplace                  237
# 2  Deirdre Maeve's Market                  280
# 3             Stop & Shop                  627
# 4     Titash Super Market                   75

# %%
#Scatter plot of School Distance Data 

rvalue = plot_lin_regress(small_df["SCHOOL DISTANCE"].astype("int64"),small_df["PRICE"],
                 "Distance to Nearest School (Meters)","Price (Dollar)","School Distance Vs Price",(100,4100000))
print(F"R-Squared equals: {rvalue**2}")
plt.show()
# Out:
# R-Squared equals: 0.00676380717915475

# %%
#Scatter plot of Hospital Distance Data 

rvalue = plot_lin_regress(small_df["HOSPITAL DISTANCE"].astype("int64"),small_df["PRICE"],
                 "Distance to Nearest Hospital (Meters)","Price (Dollar)","Hospital Distance Vs Price",(100,4100000))
print(F"R-Squared equals: {rvalue**2}")
plt.show()
# Out:
# R-Squared equals: 0.00924420528580007

# %%
#Scatter plot of Supermarket Distance Data 

rvalue = plot_lin_regress(small_df["SUPERMARKET DISTANCE"].astype("int64"),small_df["PRICE"],
                 "Distance to Nearest Supermarket (Meters)","Price (Dollar)","Supermarket Distance Vs Price",(100,4100000))
print(F"R-Squared equals: {rvalue**2}")
plt.show()
# Out:
# R-Squared equals: 0.00039595816767380715

# %%
# Analysis Text

# %%
# References
