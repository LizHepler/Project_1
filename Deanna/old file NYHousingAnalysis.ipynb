# %%
# Import relevant libraries
import requests
import json
import hvplot.pandas
import pandas as pd
from scipy.stats import linregress
from matplotlib import pyplot as plt
import random


from config import api_key

# %%
# Read in data from CSV to DataFrame
path = "./NY-House-Dataset.csv"
housing_df = pd.read_csv(path)

# %%
# Clean up data
housing_df = housing_df.drop(labels=["MAIN_ADDRESS","ADMINISTRATIVE_AREA_LEVEL_2","LOCALITY","SUBLOCALITY","STREET_NAME","LONG_NAME"], axis = 1)
housing_df.head()
# Out:
#                                          BROKERTITLE                TYPE  \
# 0        Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                Brokered by Serhant      Condo for sale
# 2                             Brokered by Sowae Corp      House for sale
# 3                                Brokered by COMPASS      Condo for sale
# 4  Brokered by Sotheby's International Realty - E...  Townhouse for sale
#
#        PRICE  BEDS       BATH  PROPERTYSQFT  \
# 0     315000     2   2.000000        1400.0
# 1  195000000     7  10.000000       17545.0
# 2     260000     4   2.000000        2015.0
# 3      69000     3   1.000000         445.0
# 4   55000000     7   2.373861       14175.0
#
#                                              ADDRESS                    STATE  \
# 0                               2 E 55th St Unit 803       New York, NY 10022
# 1  Central Park Tower Penthouse-217 W 57th New Yo...       New York, NY 10019
# 2                                   620 Sinclair Ave  Staten Island, NY 10312
# 3                            2 E 55th St Unit 908W33      Manhattan, NY 10022
# 4                                        5 E 64th St       New York, NY 10065
#
#                                    FORMATTED_ADDRESS   LATITUDE  LONGITUDE
# 0  Regis Residence, 2 E 55th St #803, New York, N...  40.761255 -73.974483
# 1             217 W 57th St, New York, NY 10019, USA  40.766393 -73.980991
# 2     620 Sinclair Ave, Staten Island, NY 10312, USA  40.541805 -74.196109
# 3               2 E 55th St, New York, NY 10022, USA  40.761398 -73.974613
# 4               5 E 64th St, New York, NY 10065, USA  40.767224 -73.969856

# %%
def plot_lin_regress(x,y,xlabel,ylabel,title,loc):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x,y)
    plt.plot(x,regress_values,"r-")
    plt.annotate(line_eq,loc,fontsize=15,color="red")
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    file_name = title.replace(" ","_")
    plt.savefig("output/"+file_name)
    return rvalue

# %%
# General housing graphs

# Bar graphs of housing prices, rooms, etc.

# %%
# Pie chart of house types

# %%
# Scatter plot comparing price to square footage



#include linear regression

# %%
# Geoapify graphs 

# Map of co-ops(?)

# %%
#Map of houses

# %%
#Map of nearby services (color code?)

# %%
# Gather data for distance to school vs price

# Set the parameters for the type of search
limit = 20
radius = 1000
category= "education.school"

# set up a parameters dictionary
params = {
    "limit":limit,
    "apiKey":api_key,  
    "categories":category
}

# Set base URL
base_url = "https://api.geoapify.com/v2/places"

# get sample (change to 100 later)
num_samples = 100
sample_indexes = random.sample(range(0,len(housing_df)),num_samples) 

prices = []
distances = []

print("Getting data. May take a few minutes")

current_count = 1

for index in sample_indexes:
    print(f"Getting nearest school to sample {current_count} of {num_samples}.")
    current_count += 1
    # Set the geographical coordinates
    latitude = housing_df.loc[index, "LATITUDE"]
    longitude = housing_df.loc[index, "LONGITUDE"]

    filters = f"circle:{longitude},{latitude},{radius}"
    bias = f"proximity:{longitude},{latitude}"

    params["filters"] = filters
    params["bias"] = bias
    nearby_school = requests.get(base_url, params=params)
    nearby_school = nearby_school.json()

    prices.append(housing_df.loc[index, "PRICE"])
    distances.append(nearby_school["features"][0]["properties"]["distance"])

distance_df = pd.DataFrame({"Price (Dollar)": prices, "Distance to Nearest School (Meters)":distances})
print("Finished getting data.")
# Out:
# Getting data. May take a few minutes
# Getting nearest school to sample 1 of 100.
# Getting nearest school to sample 2 of 100.
# Getting nearest school to sample 3 of 100.
# Getting nearest school to sample 4 of 100.
# Getting nearest school to sample 5 of 100.
# Getting nearest school to sample 6 of 100.
# Getting nearest school to sample 7 of 100.
# Getting nearest school to sample 8 of 100.
# Getting nearest school to sample 9 of 100.
# Getting nearest school to sample 10 of 100.
# Getting nearest school to sample 11 of 100.
# Getting nearest school to sample 12 of 100.
# Getting nearest school to sample 13 of 100.
# Getting nearest school to sample 14 of 100.
# Getting nearest school to sample 15 of 100.
# Getting nearest school to sample 16 of 100.
# Getting nearest school to sample 17 of 100.
# Getting nearest school to sample 18 of 100.
# Getting nearest school to sample 19 of 100.
# Getting nearest school to sample 20 of 100.
# Getting nearest school to sample 21 of 100.
# Getting nearest school to sample 22 of 100.
# Getting nearest school to sample 23 of 100.
# Getting nearest school to sample 24 of 100.
# Getting nearest school to sample 25 of 100.
# Getting nearest school to sample 26 of 100.
# Getting nearest school to sample 27 of 100.
# Getting nearest school to sample 28 of 100.
# Getting nearest school to sample 29 of 100.
# Getting nearest school to sample 30 of 100.
# Getting nearest school to sample 31 of 100.
# Getting nearest school to sample 32 of 100.
# Getting nearest school to sample 33 of 100.
# Getting nearest school to sample 34 of 100.
# Getting nearest school to sample 35 of 100.
# Getting nearest school to sample 36 of 100.
# Getting nearest school to sample 37 of 100.
# Getting nearest school to sample 38 of 100.
# Getting nearest school to sample 39 of 100.
# Getting nearest school to sample 40 of 100.
# Getting nearest school to sample 41 of 100.
# Getting nearest school to sample 42 of 100.
# Getting nearest school to sample 43 of 100.
# Getting nearest school to sample 44 of 100.
# Getting nearest school to sample 45 of 100.
# Getting nearest school to sample 46 of 100.
# Getting nearest school to sample 47 of 100.
# Getting nearest school to sample 48 of 100.
# Getting nearest school to sample 49 of 100.
# Getting nearest school to sample 50 of 100.
# Getting nearest school to sample 51 of 100.
# Getting nearest school to sample 52 of 100.
# Getting nearest school to sample 53 of 100.
# Getting nearest school to sample 54 of 100.
# Getting nearest school to sample 55 of 100.
# Getting nearest school to sample 56 of 100.
# Getting nearest school to sample 57 of 100.
# Getting nearest school to sample 58 of 100.
# Getting nearest school to sample 59 of 100.
# Getting nearest school to sample 60 of 100.
# Getting nearest school to sample 61 of 100.
# Getting nearest school to sample 62 of 100.
# Getting nearest school to sample 63 of 100.
# Getting nearest school to sample 64 of 100.
# Getting nearest school to sample 65 of 100.
# Getting nearest school to sample 66 of 100.
# Getting nearest school to sample 67 of 100.
# Getting nearest school to sample 68 of 100.
# Getting nearest school to sample 69 of 100.
# Getting nearest school to sample 70 of 100.
# Getting nearest school to sample 71 of 100.
# Getting nearest school to sample 72 of 100.
# Getting nearest school to sample 73 of 100.
# Getting nearest school to sample 74 of 100.
# Getting nearest school to sample 75 of 100.
# Getting nearest school to sample 76 of 100.
# Getting nearest school to sample 77 of 100.
# Getting nearest school to sample 78 of 100.
# Getting nearest school to sample 79 of 100.
# Getting nearest school to sample 80 of 100.
# Getting nearest school to sample 81 of 100.
# Getting nearest school to sample 82 of 100.
# Getting nearest school to sample 83 of 100.
# Getting nearest school to sample 84 of 100.
# Getting nearest school to sample 85 of 100.
# Getting nearest school to sample 86 of 100.
# Getting nearest school to sample 87 of 100.
# Getting nearest school to sample 88 of 100.
# Getting nearest school to sample 89 of 100.
# Getting nearest school to sample 90 of 100.
# Getting nearest school to sample 91 of 100.
# Getting nearest school to sample 92 of 100.
# Getting nearest school to sample 93 of 100.
# Getting nearest school to sample 94 of 100.
# Getting nearest school to sample 95 of 100.
# Getting nearest school to sample 96 of 100.
# Getting nearest school to sample 97 of 100.
# Getting nearest school to sample 98 of 100.
# Getting nearest school to sample 99 of 100.
# Getting nearest school to sample 100 of 100.
# Finished getting data.

# %%
#Scatter plot of data 
rvalue = plot_lin_regress(distance_df["Distance to Nearest School (Meters)"],distance_df["Price (Dollar)"],
                 "Distance to Nearest School (Meters)","Price (Dollar)","School Distance Vs Price",(100,20000000))
print(F"R-Squared equals: {rvalue**2}")
plt.show()
# Out:
# R-Squared equals: 0.03044812734711744

# %%
# Analysis Text

# %%
# References
